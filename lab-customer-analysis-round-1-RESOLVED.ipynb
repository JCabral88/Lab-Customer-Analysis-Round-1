# %% [markdown]
# Read the three files into python as dataframes:

# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv('/Users/JC88Main/Day1/lab-customer-analysis-round-1-master/files_for_lab/csv_files/file1.csv')
data2 = pd.read_csv('/Users/JC88Main/Day1/lab-customer-analysis-round-1-master/files_for_lab/csv_files/file2.csv')
data3 = pd.read_csv('/Users/JC88Main/Day1/lab-customer-analysis-round-1-master/files_for_lab/csv_files/file3.csv')

# %% [markdown]
# Show the DataFrame's shape.

# %%
print(data1.shape)
print(data2.shape)
print(data3.shape)
# Out:
# (4008, 11)
# (996, 11)
# (7070, 11)

# %% [markdown]
# Standardize header names.

# %%
data1.head()
# Out:
#   customer          st gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
cols = []
for column in data1.columns:
    cols.append(column.lower())
data1.columns = cols

# %%
cols = []
for column in data2.columns:
    cols.append(column.lower())
data2.columns = cols

# %%
cols = []
for column in data3.columns:
    cols.append(column.lower())
data3.columns = cols

# %%
display(data1)
display(data2)
display(data3)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# Rearrange the columns in the dataframe as needed

# %% [markdown]
# Concatenate the three dataframes

# %%
data = pd.concat([data1, data2,data3], axis=0) #Concentrate Data!
display(data)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN      M              Bachelor
# 7066  PK87824         NaN      F               College
# 7067  TD14365         NaN      M              Bachelor
# 7068  UP19263         NaN      M               College
# 7069  Y167826         NaN      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# Which columns are numerical?

# %%
data.select_dtypes('number').columns
# Out:
# Index(['income', 'monthly premium auto', 'total claim amount'], dtype='object')

# %% [markdown]
# Which columns are categorical?

# %%
data.select_dtypes(include=['object']).columns.tolist()
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer lifetime value',
#  'number of open complaints',
#  'policy type',
#  'vehicle class',
#  'state']

# %% [markdown]
# Understand the meaning of all columns

# %% [markdown]
# Delete the column education and the number of open complaints from the dataframe.

# %%
data1 = data.drop(['education', 'number of open complaints'], axis=1) #Don't understand the error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 data1 = data.drop(['education', 'number of open complaints'], axis=1)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %% [markdown]
# Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.

# %%
data1['customer lifetime value'] =  pd.to_numeric(data1['customer lifetime value'], errors='coerce')
def clv_percent(x):
    return x * 100
data1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                         NaN      0.0                  94.0
# 2                         NaN  48767.0                 108.0
# ...

# %%
display(data1)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                         NaN      0.0                  94.0
# 2                         NaN  48767.0                 108.0
# ...

# %% [markdown]
# Check for duplicate rows in the data and remove if any.

# %%
data = data.reset_index()
data = data.drop_duplicates()
data
# Out:
#        level_0  index customer          st gender customer lifetime value  \
# 0            0      0  RB50392  Washington    NaN                     NaN
# 1            1      1  QZ44356     Arizona      F              697953.59%
# 2            2      2  AI49188      Nevada      F             1288743.17%
# 3            3      3  WW63253  California      M              764586.18%
# 4            4      4  GA49547  Washington      M              536307.65%
# ...        ...    ...      ...         ...    ...                     ...
# 12069    12069   7065  LA72316         NaN      M             23405.98798
# 12070    12070   7066  PK87824         NaN      F             3096.511217
# 12071    12071   7067  TD14365         NaN      M             8163.890428
# 12072    12072   7068  UP19263         NaN      M             7524.442436
# 12073    12073   7069  Y167826         NaN      M             2611.836866
#
#         income  monthly premium auto     policy type  vehicle class  \
# ...

# %% [markdown]
# Filter out the data for customers who have an income of 0 or less.

# %%
data[data['income'] <= 0]
# Out:
#        level_0  index customer          st gender customer lifetime value  \
# 0            0      0  RB50392  Washington    NaN                     NaN
# 1            1      1  QZ44356     Arizona      F              697953.59%
# 3            3      3  WW63253  California      M              764586.18%
# 7            7      7  CF85061     Arizona      M              721610.03%
# 10          10     10  SX51350  California      M              473899.20%
# ...        ...    ...      ...         ...    ...                     ...
# 12063    12063   7059  WZ45103         NaN      F             5678.050167
# 12065    12065   7061  RX91025         NaN      M               19872.262
# 12066    12066   7062  AC13887         NaN      M             4628.995325
# 12071    12071   7067  TD14365         NaN      M             8163.890428
# 12073    12073   7069  Y167826         NaN      M             2611.836866
#
#        income  monthly premium auto     policy type  vehicle class  \
# ...
